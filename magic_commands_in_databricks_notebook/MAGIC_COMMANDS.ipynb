# %% [markdown]
# **WELCOME TO MAGIC COMMANDS LEARNING OF DATABRICKS NOTEBOOK**

# %% [markdown]
# ![](https://fplogoimages.withfloats.com/actual/68009c3a43430aff8a30419d.png)

# %% [markdown]
# ###How to call a notebook from the current notebook using %run magic command

# %%
# %run "/Workspace/Users/dhivyadharshini298@gmail.com/databricks-code-repo/databricks_workouts_2025_WE47/1_DATABRICKS_NOTEBOOK_FUNDAMENTALS/4_child_notebook"

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.volumewe47_datalake;

# %%
# %fs ls "dbfs:///Volumes/workspace/default/volumewe47_datalake"

# %%
# %fs cp "/Volumes/workspace/default/volumewe47_datalake/patients.csv" "/Volumes/workspace/default/volumewe47_datalake/patients.csv_copy.csv"

# %%
dbutils.fs.cp("dbfs:/Volumes/workspace/default/volumewe47_datalake/patients.csv","/Volumes/workspace/default/volumewe47_datalake/patients.csv_copy2.csv")
dbutils.fs.rm("/Volumes/workspace/default/volumewe47_datalake/patients.csv_copy.csv")

# %%
# %sql
create table if not exists default.cities(id int, city string);
insert into default.cities values (1, 'chicago'), (2, 'new york'), (3, 'los angeles');
select * from cities;

# %%
# %python
spark.sql("select * from cities").explain(True)

# %%
# %sql
update cities set city="Texas" where id = 1;
select * from cities;

# %%
# %sql
show create table cities;

# %%
# %sql
from cities select*;

# %%
# %sql
select * from cities;

# %%
# %python
from pyspark.sql.session import SparkSession
#import pyspark.sql.session as sprk
print(spark)
spark1 = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
print(spark1)
df1 = spark1.read.csv("/Volumes/workspace/default/volumewe47_datalake/patients.csv",header=True)
display(df1)

# %%
df1.where("married='Yes'").write.saveAsTable("default.we47_patients")

# %%
# %pip install pypi
