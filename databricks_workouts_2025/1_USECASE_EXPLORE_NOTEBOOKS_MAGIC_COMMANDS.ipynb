# %% [markdown]
# #BASIC MAGIC AND MARKDOWNS USED IN DATABRICKS

# %% [markdown]
# ##TASK-1:Document the Notebook Using mark down %md

# %% [markdown]
# A good Title <br>
# Description of the task<br>
# Your name in some color<br>
# Bring our Team photo from the given url "https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg"<br>
# Use headings, bold, italics appropriately.

# %% [markdown]
# **WELCOME TO BASIC DATABRICKS NOTEBOOK**

# %% [markdown]
# this notebook gives few idea regarding basic markdowns and magic commands which helps making a notebook accessible and more understandable with it's features

# %% [markdown]
# this notebook created by $${\color{pink}DIVYADHARSHINI}$$

# %% [markdown]
# attaching our inceptez we47 team picture in this notebook<br>
# ![](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg)

# %% [markdown]
# lets see how to make a statement or a word in bold and italics

# %% [markdown]
# **Databricks = Managed Apache Spark Platform + Cloud**<br>
#
# *Databricks is designed to manage large datasets across clusters of computers, providing a comprehensive, enterprise-ready cloud platform for data engineering, data warehousing, machine learning, AI, and analytics with security+catalog+advanced libraries powered by Databricks on top of Apache Spark.*

# %% [markdown]
# ##TASK-2:Create a volume namely usage_metrics using sql magic command %sql

# %%
# %sql
create volume if not exists workspace.default.usage_metrics;

# %% [markdown]
# ##TASK-3:Create a child notebook "4_child_nb_dataload" and write code to load data, Using the requests library, perform api call to pull data from "https://public.tableau.com/app/sample-data/mobile_os_usage.csv" into a python variable using the magic command %py and write the data into the created volume "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv" using the above variable.text using the magic command dbutils.fs.put("volume",variable.text,overwrite=True)

# %%
Task-3 child notebbok has been created in a seperate notebook

# %% [markdown]
# ##TASK-4:Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run "/Workspace/Users/dhivyadharshini298@gmail.com/4_child_nb_dataload"

# %% [markdown]
# ##TASK-5:list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
# %fs ls "/Volumes/workspace/default/usage_metrics"

# %%
# %fs ls "/Volumes/workspace/default/volumewe47_datalake"

# %%
# %fs head "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# %% [markdown]
# ##TASK-6: Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command %python

# %%
# %python
df1=spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",header=True)
display(df1)

# %% [markdown]
# ##TASK-7:Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python

# %%
df1 = df1.withColumnRenamed(
    "Mobile Operating System", "Mobile_Operating_System"
).withColumnRenamed(
    "Percent of Usage", "Percent_of_Usage"
)

# %%
df1.write.saveAsTable("default.mobile_os_usage")

# %% [markdown]
# ##TASK-8:Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python

# %%
# %sql
select * from mobile_os_usage;

# %%
# %python
spark.sql("select * from mobile_os_usage").show()

# %%
# %python
display(spark.sql("select * from mobile_os_usage"))

# %% [markdown]
# ##TASK-9:Create a python function to convert the given input to upper case

# %%
# %python
def convert_to_upper(text):
    return text.upper()
print(convert_to_upper("hello"))

# %% [markdown]
# ##TASK-10:Install pandas library using the pip python magic command %pip

# %%
# %pip install pandas

# %%
# %restart_python

# %% [markdown]
# ##TASK-11:Import pandas, using pandas read_csv and display the output using the magic command %python

# %%
# %python
import pandas as pd
df=pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df)

# %% [markdown]
# ##TASK-12:echo "Magic commands tasks completed" using the linux shell magic command %sh

# %%
# %sh
echo "Magic commands tasks completed"
