# %% [markdown]
# #Usecase2- Healthcare Data Utilities

# %% [markdown]
# ##Objective

# %% [markdown]
# This notebook demonstrates how to design Databricks notebook using Markdown and how to work with Databricks utilities such as dbutils.fs, dbutils.widgets, and dbutils.notebook using Volumes.

# %% [markdown]
# ###TASK-1: Define Base Paths using python variable

# %% [markdown]
# base_path = "/Volumes/workspace/default/volumewd36"
# Create raw_path, processed_path and archive_path as given below...<br>
# raw_path = f"{base_path}/raw"<br>
# processed_path = f"{base_path}/processed"<br>
# archive_path = f"{base_path}/archive"<br>

# %%
# %python
base_path= "/Volumes/workspace/default/volumewe47_datalake"
raw_path = f"{base_path}/raw"
processed_path = f"{base_path}/processed"
archive_path = f"{base_path}/archive"

# %%
print("Raw Path:", raw_path)
print("Processed Path:", processed_path)
print("Archive Path:", archive_path)

# %% [markdown]
# ###TASK-2:dbutils Usecase – Create Directories using the above path variables..

# %%
dbutils.fs.mkdirs(raw_path)
dbutils.fs.mkdirs(processed_path)
dbutils.fs.mkdirs(archive_path)

# %% [markdown]
# ###TASK-3:butils Usecase – Create Sample Healthcare File

# %% [markdown]
# sample_data = """patient_id,patient_name,age,gender 1,John Doe,68,M 2,Jane Smith,54,F """<br>
# TODO: Write this file content into raw folder created earlier... using dbutils.fs.......

# %%
base_path= "/Volumes/workspace/default/volumewe47_datalake"
raw_path = f"{base_path}/raw"

sample_data = """patient_id,patient_name,age,gender 
1,John Doe,68,M 
2,Jane Smith,54,F """
file_path=f"{raw_path}/healthcare_patients.csv"
dbutils.fs.put(file_path, sample_data, overwrite=True)

# %% [markdown]
# ###TASK-4:dbutils Usecase - list the file created

# %% [markdown]
# TODO: List all files available in raw folder using the dbutils command
# dbutils.fs......

# %%
# %python
dbutils.fs.ls(raw_path)

# %% [markdown]
# ###TASK-5:dbutils Usecase – Copy File (raw → processed)

# %%
# %python
dbutils.fs.cp("/Volumes/workspace/default/volumewe47_datalake/raw/healthcare_patients.csv", "/Volumes/workspace/default/volumewe47_datalake/processed/healthcare_patients.csv")

# %% [markdown]
# ###TASK-6:dbutils widget usecase - Create dropdown and text widgets...

# %% [markdown]
# TODO: Create a dropdown widget for environment (dev, qa, prod) using<br>
# TODO: Create a text widget for owner name

# %%
dbutils.widgets.dropdown("environment", "dev", ["dev", "qa", "prod"], "Choose Environment" )

# %%
dbutils.widgets.text("owner_name","DIVYA","enter the owner name here")

# %% [markdown]
# ###TASK-7:dbutils widget Usecase – Read Widget Values environment and owner and print in the screen

# %%
environment=dbutils.widgets.get("environment")
owner_name=dbutils.widgets.get("owner_name")
print(environment)
print(owner_name)

# %% [markdown]
# ###TASK-8:dbutils widget Usecase – Move the above processed File to Archive

# %%
dbutils.fs.mv("/Volumes/workspace/default/volumewe47_datalake/processed/healthcare_patients.csv","/Volumes/workspace/default/volumewe47_datalake/archive/healthcare_patients.csv")

# %% [markdown]
# ###TASK-9:dbutils notebook usecase - Run the notebook4 using the dbutils command /Workspace/Users/infoblisstech@gmail.com/databricks-code-repo/databricks_workouts_2025/1_USECASES_NB_FUNDAMENTALS/4_child_nb_dataload

# %%
dbutils.notebook.run("/Workspace/Users/dhivyadharshini298@gmail.com/databricks-code-repository/databricks_workouts_2025/4_child_nb_dataload",90)
print("child notebook executed")

# %% [markdown]
# ###TASK-10:dbutils notebook usecase - exit this notebook

# %% [markdown]
# TODO: Exit notebook with a success message dbutils.notebook._____("Pipeline completed successfully")

# %%
dbutils.notebook.exit("Pipeline completed successfully")
