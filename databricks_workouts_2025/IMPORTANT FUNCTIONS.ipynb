# %% [markdown]
# #this notebook holds some of the important functions used in Databricks pyspark

# %% [markdown]
# ##important Datbricks/spark functions

# %% [markdown]
# ###Data Reading & Writing (I/O)

# %% [markdown]
# ####1. Read function()

# %% [markdown]
# spark.read.csv()<br>
# spark.read.json()<br>
# spark.read.parquet()<br>
# spark.read.orc()<br>
# spark.read.table()<br>
# spark.read.format()

# %% [markdown]
# ####2. Write function()

# %% [markdown]
# df.write.csv()<br>
# df.write.parquet()<br>
# df.write.orc()<br>
# df.write.save()<br>
# df.write.saveAsTable()<br>
# df.write.insertInto()

# %% [markdown]
# ####3. Common Options()

# %% [markdown]
# .option("header","true")<br>
# .option("inferSchema","true")<br>
# .option("mergeSchema","true")<br>
# .option("recursiveFileLookup","true")

# %% [markdown]
# ###DataFrame Inspection & Debugging

# %% [markdown]
# df.show()<br>
# df.printSchema()<br>
# df.dtypes<br>
# df.columns<br>
# df.count()<br>
# df.describe()<br>
# df.summary()<br>
# display(df)

# %%
spark.sql("select '1a23' as col1").where("col1 not rlike '[a-zA-Z]'").show()
