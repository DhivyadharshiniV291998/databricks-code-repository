# %%
# %run /Workspace/Users/dhivyadharshini298@gmail.com/databricks-code-repository/Bread_and_Butter_Transformation_Analytical_operations_DSL/5.DATA_WRANGLING

# %% [markdown]
# #Egress of the required DFs created at any of the above stages, we have persist in the tables or in a form of files or to some external systems.

# %%
standard_df6.write.parquet("/Volumes/workspace/default/volumewe47_datalake/munged_cust_data",mode='overwrite')
final_denormalized_df1.write.mode("overwrite").format("delta").save("/Volumes/workspace/default/volumewe47_datalake/starschema_cust_trans_data")
