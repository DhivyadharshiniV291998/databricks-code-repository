# %% [markdown]
# **LETS CREATE SUMMARY OF FUNDAMENTALS OF PYTHON LEARNING**

# %% [markdown]
# ##1. Basic programming fundamentals

# %% [markdown]
# ###A. Intent Block based coding

# %% [markdown]
# for managing the program more efficiently and for better readability of the code

# %% [markdown]
# #### program-1: Python program related to indentation

# %%
# %python
aspirants_list=['Jeeva','Bharathi','Vaanmathy','Nag']
for aspirants in aspirants_list:
    print("good afternoon ",aspirants)
    print("good after all aspirants")

# %% [markdown]
# ###B. Comments

# %% [markdown]
# improve the understanding and usability of the code efficiently
# - 2 purposes
# - for creating dead codes and for giving descriptions about a line or block of code

# %% [markdown]
# #### program-2: giving comments to a program

# %% [markdown]
# """
# This script is part of Inceptez Technologies' training tracker.
# It stores the number of students and trainers,
# calculates the total participants involved in the training program,
# and prints the final count for tracking purposes.
# """

# %%
students = 100
trainers = 2
total = students + trainers
print(total)

# %% [markdown]
# ###C. Quotes

# %% [markdown]
# - single quote
# - double quotes
# - triple quotes

# %% [markdown]
# #### program-3: how to play with quotes in python programming

# %%
print("""This is Inceptez's "Python" class for Data Engineers & AI Engineers""")#we can either use''' ''' (or)""" """

# %% [markdown]
# ###D. Variables & Values

# %% [markdown]
# - Dynamic Inference (automatically identifies the data type),
# - Dynamic Typed(dynamically changes the data type from int to float),
# - Strongly Typed(can combine similar family of data type together)

# %% [markdown]
# ###E. Naming Conventions

# %% [markdown]
# - camel case,
# - snake case and
# - pascal/init upper case

# %% [markdown]
# ###F. Types (Simple) and Casting

# %% [markdown]
# used to check a given TYPE is of what data-type we expect and type casting. Functions used here are type(), str/float/int(), isinstance()

# %% [markdown]
# ###G. Input & Output operations

# %% [markdown]
# - **INPUT**[input will take the input using keyboard via console. Few characteristic - if not prompted, blank space will get prompted; input will return by default every input as string type]
#
# - **OUTPUT**[semi colon can be used to separate a statement if we write multiple statements in one line.]

# %% [markdown]
# # 2.OTHER MARKDOWNS IN DATABRICKS

# %% [markdown]
# ##A. let's learn about bold and italics

# %% [markdown]
# - BOLD <br>
# **Databricks = Managed Apache Spark Platform + Cloud**
#
# - *Italics* <br>
# *Databricks is designed to manage large datasets across clusters of computers, providing a comprehensive, enterprise-ready cloud platform for data engineering, data warehousing, machine learning, AI, and analytics with security+catalog+advanced libraries powered by Databricks on top of Apache Spark.*

# %% [markdown]
# ##B. let's learn about how to add color codes in a statement or a word

# %% [markdown]
# $${\color{RED}Spark is a lightning fast}$$

# %% [markdown]
# ##C. lets learn about how to embed an URL

# %% [markdown]
# click here for [Inceptez webpage](https://www.inceptez.in/)
